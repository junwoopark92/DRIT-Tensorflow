# %%
import glob
import os

# %%
sorted(glob.glob('./dataset/blond2brown/trainA/*'))[:1800]
# Out:
# ['./dataset/blond2brown/trainA/001056.jpg',
#  './dataset/blond2brown/trainA/001058.jpg',
#  './dataset/blond2brown/trainA/001060.jpg',
#  './dataset/blond2brown/trainA/001062.jpg',
#  './dataset/blond2brown/trainA/001068.jpg',
#  './dataset/blond2brown/trainA/001070.jpg',
#  './dataset/blond2brown/trainA/001075.jpg',
#  './dataset/blond2brown/trainA/001081.jpg',
#  './dataset/blond2brown/trainA/001094.jpg',
#  './dataset/blond2brown/trainA/001095.jpg',
#  './dataset/blond2brown/trainA/001111.jpg',
#  './dataset/blond2brown/trainA/001116.jpg',
#  './dataset/blond2brown/trainA/001118.jpg',
#  './dataset/blond2brown/trainA/001119.jpg',
#  './dataset/blond2brown/trainA/001121.jpg',
#  './dataset/blond2brown/trainA/001130.jpg',
#  './dataset/blond2brown/trainA/001132.jpg',
#  './dataset/blond2brown/trainA/001136.jpg',
#  './dataset/blond2brown/trainA/001142.jpg',
#  './dataset/blond2brown/trainA/001148.jpg',
#  './dataset/blond2brown/trainA/001150.jpg',
# ...

# %%
src = './dataset/blond2brown/trainA/'
dst = './dataset/blond2brown/testA/'

# %%
for filepath in sorted(glob.glob('./dataset/blond2brown/trainA/*'))[:1800]:
    print(filepath, dst+filepath.split('/')[-1])
    os.rename(filepath, dst+filepath.split('/')[-1])
# Out:
# ./dataset/blond2brown/trainA/001056.jpg ./dataset/blond2brown/testA/001056.jpg
# ./dataset/blond2brown/trainA/001058.jpg ./dataset/blond2brown/testA/001058.jpg
# ./dataset/blond2brown/trainA/001060.jpg ./dataset/blond2brown/testA/001060.jpg
# ./dataset/blond2brown/trainA/001062.jpg ./dataset/blond2brown/testA/001062.jpg
# ./dataset/blond2brown/trainA/001068.jpg ./dataset/blond2brown/testA/001068.jpg
# ./dataset/blond2brown/trainA/001070.jpg ./dataset/blond2brown/testA/001070.jpg
# ./dataset/blond2brown/trainA/001075.jpg ./dataset/blond2brown/testA/001075.jpg
# ./dataset/blond2brown/trainA/001081.jpg ./dataset/blond2brown/testA/001081.jpg
# ./dataset/blond2brown/trainA/001094.jpg ./dataset/blond2brown/testA/001094.jpg
# ./dataset/blond2brown/trainA/001095.jpg ./dataset/blond2brown/testA/001095.jpg
# ./dataset/blond2brown/trainA/001111.jpg ./dataset/blond2brown/testA/001111.jpg
# ./dataset/blond2brown/trainA/001116.jpg ./dataset/blond2brown/testA/001116.jpg
# ...

# %%
len(glob.glob('./dataset/male2female/trainA/*')), len(glob.glob('./dataset/male2female/testA/*'))
# Out:
# (82434, 2000)

# %%
# !ls dataset
# Out:
# black2brown	 brown2blond.zip      male2female.zip
# black2brown.zip  download_dataset.sh  smile2nosmile
# blond2brown	 male2female	      smile2nosmile.zip
